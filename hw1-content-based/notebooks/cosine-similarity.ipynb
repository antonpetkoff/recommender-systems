# %%
from sklearn.datasets import fetch_20newsgroups

newsgroups_train = fetch_20newsgroups(subset='train')

# %%
import pandas as pd

df = pd.DataFrame({
    'doc_id': list(map(lambda filename: '/'.join(filename.split('/')[-2:]), newsgroups_train.filenames)),
    'topic': list(map(lambda topic_id: newsgroups_train.target_names[topic_id], newsgroups_train.target)),
    'text': newsgroups_train.data,
})

df = df.set_index('doc_id')

df
# Out:
#                                                    topic  \
# doc_id
# rec.autos/102994                               rec.autos
# comp.sys.mac.hardware/51861        comp.sys.mac.hardware
# comp.sys.mac.hardware/51879        comp.sys.mac.hardware
# comp.graphics/38242                        comp.graphics
# sci.space/60880                                sci.space
# talk.politics.guns/54525              talk.politics.guns
# sci.med/58080                                    sci.med
# comp.sys.ibm.pc.hardware/60249  comp.sys.ibm.pc.hardware
# comp.os.ms-windows.misc/10008    comp.os.ms-windows.misc
# comp.sys.mac.hardware/50502        comp.sys.mac.hardware
# rec.motorcycles/104091                   rec.motorcycles
# talk.religion.misc/83457              talk.religion.misc
# comp.sys.mac.hardware/51621        comp.sys.mac.hardware
# sci.space/61165                                sci.space
# misc.forsale/76142                          misc.forsale
# alt.atheism/51242                            alt.atheism
# comp.graphics/38633                        comp.graphics
# rec.autos/102812                               rec.autos
# sci.electronics/52816                    sci.electronics
# comp.windows.x/67212                      comp.windows.x
# alt.atheism/53216                            alt.atheism
# rec.sport.hockey/53747                  rec.sport.hockey
# misc.forsale/75973                          misc.forsale
# comp.os.ms-windows.misc/9618     comp.os.ms-windows.misc
# comp.sys.mac.hardware/51613        comp.sys.mac.hardware
# comp.graphics/37915                        comp.graphics
# sci.electronics/53670                    sci.electronics
# rec.sport.baseball/104428             rec.sport.baseball
# soc.religion.christian/20558      soc.religion.christian
# rec.autos/102990                               rec.autos
# ...                                                  ...
# comp.sys.mac.hardware/51932        comp.sys.mac.hardware
# rec.sport.baseball/104363             rec.sport.baseball
# sci.space/61176                                sci.space
# rec.sport.hockey/53762                  rec.sport.hockey
# rec.autos/103003                               rec.autos
# comp.graphics/38501                        comp.graphics
# comp.sys.mac.hardware/51823        comp.sys.mac.hardware
# rec.autos/103185                               rec.autos
# rec.autos/102914                               rec.autos
# misc.forsale/74811                          misc.forsale
# rec.sport.hockey/53809                  rec.sport.hockey
# comp.sys.ibm.pc.hardware/60156  comp.sys.ibm.pc.hardware
# rec.sport.baseball/102644             rec.sport.baseball
# comp.sys.ibm.pc.hardware/60715  comp.sys.ibm.pc.hardware
# rec.sport.hockey/53979                  rec.sport.hockey
# talk.politics.mideast/76308        talk.politics.mideast
# soc.religion.christian/20902      soc.religion.christian
# misc.forsale/76576                          misc.forsale
# sci.crypt/15607                                sci.crypt
# comp.sys.mac.hardware/51725        comp.sys.mac.hardware
# talk.religion.misc/84087              talk.religion.misc
# talk.politics.mideast/75982        talk.politics.mideast
# comp.sys.ibm.pc.hardware/60496  comp.sys.ibm.pc.hardware
# misc.forsale/76143                          misc.forsale
# comp.windows.x/66943                      comp.windows.x
# sci.med/58069                                    sci.med
# comp.sys.mac.hardware/51712        comp.sys.mac.hardware
# comp.sys.ibm.pc.hardware/60695  comp.sys.ibm.pc.hardware
# comp.graphics/38319                        comp.graphics
# rec.motorcycles/104440                   rec.motorcycles
#
#                                                                              text
# doc_id
# rec.autos/102994                From: lerxst@wam.umd.edu (where's my thing)\nS...
# comp.sys.mac.hardware/51861     From: guykuo@carson.u.washington.edu (Guy Kuo)...
# comp.sys.mac.hardware/51879     From: twillis@ec.ecn.purdue.edu (Thomas E Will...
# comp.graphics/38242             From: jgreen@amber (Joe Green)\nSubject: Re: W...
# sci.space/60880                 From: jcm@head-cfa.harvard.edu (Jonathan McDow...
# talk.politics.guns/54525        From: dfo@vttoulu.tko.vtt.fi (Foxvog Douglas)\...
# sci.med/58080                   From: bmdelane@quads.uchicago.edu (brian manni...
# comp.sys.ibm.pc.hardware/60249  From: bgrubb@dante.nmsu.edu (GRUBB)\nSubject: ...
# comp.os.ms-windows.misc/10008   From: holmes7000@iscsvax.uni.edu\nSubject: WIn...
# comp.sys.mac.hardware/50502     From: kerr@ux1.cso.uiuc.edu (Stan Kerr)\nSubje...
# rec.motorcycles/104091          From: irwin@cmptrc.lonestar.org (Irwin Arnstei...
# talk.religion.misc/83457        From: david@terminus.ericsson.se (David Bold)\...
# comp.sys.mac.hardware/51621     From: rodc@fc.hp.com (Rod Cerkoney)\nSubject: ...
# sci.space/61165                 From: dbm0000@tm0006.lerc.nasa.gov (David B. M...
# misc.forsale/76142              From: jllee@acsu.buffalo.edu (Johnny L Lee)\nS...
# alt.atheism/51242               From: mathew <mathew@mantis.co.uk>\nSubject: R...
# comp.graphics/38633             From: ab@nova.cc.purdue.edu (Allen B)\nSubject...
# rec.autos/102812                From: CPKJP@vm.cc.latech.edu (Kevin Parker)\nS...
# sci.electronics/52816           From: ritley@uimrl7.mrl.uiuc.edu ()\nSubject: ...
# comp.windows.x/67212            From: abarden@tybse1.uucp (Ann Marie Barden)\n...
# alt.atheism/53216               From: keith@cco.caltech.edu (Keith Allan Schne...
# rec.sport.hockey/53747          From: leunggm@odin.control.utoronto.ca (Gary L...
# misc.forsale/75973              From: rpwhite@cs.nps.navy.mil (rpwhite)\nSubje...
# comp.os.ms-windows.misc/9618    From: csyphers@uafhp..uark.edu (Chris Syphers)...
# comp.sys.mac.hardware/51613     From: nodine@lcs.mit.edu (Mark H. Nodine)\nSub...
# comp.graphics/37915             From: kph2q@onyx.cs.Virginia.EDU (Kenneth Hinc...
# sci.electronics/53670           From: nagle@netcom.com (John Nagle)\nSubject: ...
# rec.sport.baseball/104428       From: r4938585@joplin.biosci.arizona.edu (Doug...
# soc.religion.christian/20558    From: jonh@david.wheaton.edu (Jonathan Hayward...
# rec.autos/102990                From: jimf@centerline.com (Jim Frost)\nSubject...
# ...                                                                           ...
# comp.sys.mac.hardware/51932     Distribution: world\nFrom: elenay_creations@tc...
# rec.sport.baseball/104363       From: re4@prism.gatech.EDU (RUSSELL EARNEST)\n...
# sci.space/61176                 From: looper@cco.caltech.edu (Mark D. Looper)\...
# rec.sport.hockey/53762          From: gballent@hudson.UVic.CA (Greg  Ballentin...
# rec.autos/103003                From: cka52397@uxa.cso.uiuc.edu (OrioleFan@uiu...
# comp.graphics/38501             From: max@slinky.NYU.EDU (David Max)\nSubject:...
# comp.sys.mac.hardware/51823     From: hades@coos.dartmouth.edu (Brian V. Hughe...
# rec.autos/103185                From: c23reg@kocrsv01.delcoelect.com (Ron Gask...
# rec.autos/102914                From: callison@uokmax.ecn.uoknor.edu (James P....
# misc.forsale/74811              From: bigelos@hobo.ECE.ORST.EDU (Space Gigolo)...
# rec.sport.hockey/53809          From: LMARSHA@cms.cc.wayne.edu (Laurie Marshal...
# comp.sys.ibm.pc.hardware/60156  From: gt5735a@prism.gatech.EDU (Mark Devaney)\...
# rec.sport.baseball/102644       From: pkeenan@s.psych.uiuc.edu (Patricia Keena...
# comp.sys.ibm.pc.hardware/60715  From: CCMB <CCMB@MUSICA.MCGILL.CA>\nSubject: W...
# rec.sport.hockey/53979          From: cbetz@radioman.cray.com (Charles Betz  {...
# talk.politics.mideast/76308     From: 2120788@hydra.maths.unsw.EDU.AU ()\nSubj...
# soc.religion.christian/20902    From: aa888@freenet.carleton.ca (Mark Baker)\n...
# misc.forsale/76576              From: zmed16@trc.amoco.com (Michael)\nSubject:...
# sci.crypt/15607                 From: rdippold@qualcomm.com (Ron "Asbestos" Di...
# comp.sys.mac.hardware/51725     From: bchuang@css.itd.umich.edu (Ben Chuang)\n...
# talk.religion.misc/84087        From: Pegasus@aaa.uoregon.edu (Pegasus)\nSubje...
# talk.politics.mideast/75982     From: shaig@composer.think.com (Shai Guday)\nS...
# comp.sys.ibm.pc.hardware/60496  From: mrj@cs.su.oz.au (Mark James)\nSubject: R...
# misc.forsale/76143              From: chein@eng.auburn.edu (Tsan Heui)\nSubjec...
# comp.windows.x/66943            From: adrian@ora.COM (Adrian Nye)\nSubject: im...
# sci.med/58069                   From: jim.zisfein@factory.com (Jim Zisfein) \n...
# comp.sys.mac.hardware/51712     From: ebodin@pearl.tufts.edu\nSubject: Screen ...
# comp.sys.ibm.pc.hardware/60695  From: westes@netcom.com (Will Estes)\nSubject:...
# comp.graphics/38319             From: steve@hcrlgw (Steven Collins)\nSubject: ...
# rec.motorcycles/104440          From: gunning@cco.caltech.edu (Kevin J. Gunnin...
#
# [11314 rows x 2 columns]

# %%
from nltk.tokenize import TweetTokenizer
tweet_tok = TweetTokenizer()

from nltk.corpus import stopwords
stop_words = stopwords.words('english')

from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

def clean_text(text):
    # TODO: remove metadata
    # TODO: Rake
    return [
        stemmer.stem(word.lower())
        for word in tweet_tok.tokenize(text)
        if word.isalpha() and not word in stop_words
    ]

# %%
sample = list(df['text'].head(2))
list(map(clean_text, sample))
# Out:
# [['from',
#   'thing',
#   'subject',
#   'what',
#   'car',
#   'organ',
#   'univers',
#   'maryland',
#   'colleg',
#   'park',
#   'line',
#   'i',
#   'wonder',
#   'anyon',
#   'could',
#   'enlighten',
#   'car',
#   'i',
#   'saw',
#   'day',
#   'it',
#   'door',
#   'sport',
#   'car',
#   'look',
#   'late',
#   'earli',
#   'it',
#   'call',
#   'bricklin',
#   'the',
#   'door',
#   'realli',
#   'small',
#   'in',
#   'addit',
#   'front',
#   'bumper',
#   'separ',
#   'rest',
#   'bodi',
#   'thi',
#   'i',
#   'know',
#   'if',
#   'anyon',
#   'tellm',
#   'model',
#   'name',
#   'engin',
#   'spec',
#   'year',
#   'product',
#   'car',
#   'made',
#   'histori',
#   'whatev',
#   'info',
#   'funki',
#   'look',
#   'car',
#   'pleas',
#   'thank',
#   'il',
#   'brought',
#   'neighborhood',
#   'lerxst'],
#  ['from',
#   'guy',
#   'kuo',
#   'subject',
#   'si',
#   'clock',
#   'poll',
#   'final',
#   'call',
#   'summari',
#   'final',
#   'call',
#   'si',
#   'clock',
#   'report',
#   'keyword',
#   'si',
#   'acceler',
#   'clock',
#   'upgrad',
#   'd',
#   'shelley',
#   'organ',
#   'univers',
#   'washington',
#   'line',
#   'a',
#   'fair',
#   'number',
#   'brave',
#   'soul',
#   'upgrad',
#   'si',
#   'clock',
#   'oscil',
#   'share',
#   'experi',
#   'poll',
#   'pleas',
#   'send',
#   'brief',
#   'messag',
#   'detail',
#   'experi',
#   'procedur',
#   'top',
#   'speed',
#   'attain',
#   'cpu',
#   'rate',
#   'speed',
#   'add',
#   'card',
#   'adapt',
#   'heat',
#   'sink',
#   'hour',
#   'usag',
#   'per',
#   'day',
#   'floppi',
#   'disk',
#   'function',
#   'floppi',
#   'especi',
#   'request',
#   'i',
#   'summar',
#   'next',
#   'two',
#   'day',
#   'pleas',
#   'add',
#   'network',
#   'knowledg',
#   'base',
#   'done',
#   'clock',
#   'upgrad',
#   'answer',
#   'poll',
#   'thank',
#   'guy',
#   'kuo']]

# %%
df['text_clean'] = df['text'].apply(clean_text).apply(lambda x: ' '.join(x))

# %%
df
# Out:
#                                                    topic  \
# doc_id
# rec.autos/102994                               rec.autos
# comp.sys.mac.hardware/51861        comp.sys.mac.hardware
# comp.sys.mac.hardware/51879        comp.sys.mac.hardware
# comp.graphics/38242                        comp.graphics
# sci.space/60880                                sci.space
# talk.politics.guns/54525              talk.politics.guns
# sci.med/58080                                    sci.med
# comp.sys.ibm.pc.hardware/60249  comp.sys.ibm.pc.hardware
# comp.os.ms-windows.misc/10008    comp.os.ms-windows.misc
# comp.sys.mac.hardware/50502        comp.sys.mac.hardware
# rec.motorcycles/104091                   rec.motorcycles
# talk.religion.misc/83457              talk.religion.misc
# comp.sys.mac.hardware/51621        comp.sys.mac.hardware
# sci.space/61165                                sci.space
# misc.forsale/76142                          misc.forsale
# alt.atheism/51242                            alt.atheism
# comp.graphics/38633                        comp.graphics
# rec.autos/102812                               rec.autos
# sci.electronics/52816                    sci.electronics
# comp.windows.x/67212                      comp.windows.x
# alt.atheism/53216                            alt.atheism
# rec.sport.hockey/53747                  rec.sport.hockey
# misc.forsale/75973                          misc.forsale
# comp.os.ms-windows.misc/9618     comp.os.ms-windows.misc
# comp.sys.mac.hardware/51613        comp.sys.mac.hardware
# comp.graphics/37915                        comp.graphics
# sci.electronics/53670                    sci.electronics
# rec.sport.baseball/104428             rec.sport.baseball
# soc.religion.christian/20558      soc.religion.christian
# rec.autos/102990                               rec.autos
# ...                                                  ...
# comp.sys.mac.hardware/51932        comp.sys.mac.hardware
# rec.sport.baseball/104363             rec.sport.baseball
# sci.space/61176                                sci.space
# rec.sport.hockey/53762                  rec.sport.hockey
# rec.autos/103003                               rec.autos
# comp.graphics/38501                        comp.graphics
# comp.sys.mac.hardware/51823        comp.sys.mac.hardware
# rec.autos/103185                               rec.autos
# rec.autos/102914                               rec.autos
# misc.forsale/74811                          misc.forsale
# rec.sport.hockey/53809                  rec.sport.hockey
# comp.sys.ibm.pc.hardware/60156  comp.sys.ibm.pc.hardware
# rec.sport.baseball/102644             rec.sport.baseball
# comp.sys.ibm.pc.hardware/60715  comp.sys.ibm.pc.hardware
# rec.sport.hockey/53979                  rec.sport.hockey
# talk.politics.mideast/76308        talk.politics.mideast
# soc.religion.christian/20902      soc.religion.christian
# misc.forsale/76576                          misc.forsale
# sci.crypt/15607                                sci.crypt
# comp.sys.mac.hardware/51725        comp.sys.mac.hardware
# talk.religion.misc/84087              talk.religion.misc
# talk.politics.mideast/75982        talk.politics.mideast
# comp.sys.ibm.pc.hardware/60496  comp.sys.ibm.pc.hardware
# misc.forsale/76143                          misc.forsale
# comp.windows.x/66943                      comp.windows.x
# sci.med/58069                                    sci.med
# comp.sys.mac.hardware/51712        comp.sys.mac.hardware
# comp.sys.ibm.pc.hardware/60695  comp.sys.ibm.pc.hardware
# comp.graphics/38319                        comp.graphics
# rec.motorcycles/104440                   rec.motorcycles
#
#                                                                              text  \
# doc_id
# rec.autos/102994                From: lerxst@wam.umd.edu (where's my thing)\nS...
# comp.sys.mac.hardware/51861     From: guykuo@carson.u.washington.edu (Guy Kuo)...
# comp.sys.mac.hardware/51879     From: twillis@ec.ecn.purdue.edu (Thomas E Will...
# comp.graphics/38242             From: jgreen@amber (Joe Green)\nSubject: Re: W...
# sci.space/60880                 From: jcm@head-cfa.harvard.edu (Jonathan McDow...
# talk.politics.guns/54525        From: dfo@vttoulu.tko.vtt.fi (Foxvog Douglas)\...
# sci.med/58080                   From: bmdelane@quads.uchicago.edu (brian manni...
# comp.sys.ibm.pc.hardware/60249  From: bgrubb@dante.nmsu.edu (GRUBB)\nSubject: ...
# comp.os.ms-windows.misc/10008   From: holmes7000@iscsvax.uni.edu\nSubject: WIn...
# comp.sys.mac.hardware/50502     From: kerr@ux1.cso.uiuc.edu (Stan Kerr)\nSubje...
# rec.motorcycles/104091          From: irwin@cmptrc.lonestar.org (Irwin Arnstei...
# talk.religion.misc/83457        From: david@terminus.ericsson.se (David Bold)\...
# comp.sys.mac.hardware/51621     From: rodc@fc.hp.com (Rod Cerkoney)\nSubject: ...
# sci.space/61165                 From: dbm0000@tm0006.lerc.nasa.gov (David B. M...
# misc.forsale/76142              From: jllee@acsu.buffalo.edu (Johnny L Lee)\nS...
# alt.atheism/51242               From: mathew <mathew@mantis.co.uk>\nSubject: R...
# comp.graphics/38633             From: ab@nova.cc.purdue.edu (Allen B)\nSubject...
# rec.autos/102812                From: CPKJP@vm.cc.latech.edu (Kevin Parker)\nS...
# sci.electronics/52816           From: ritley@uimrl7.mrl.uiuc.edu ()\nSubject: ...
# comp.windows.x/67212            From: abarden@tybse1.uucp (Ann Marie Barden)\n...
# alt.atheism/53216               From: keith@cco.caltech.edu (Keith Allan Schne...
# rec.sport.hockey/53747          From: leunggm@odin.control.utoronto.ca (Gary L...
# misc.forsale/75973              From: rpwhite@cs.nps.navy.mil (rpwhite)\nSubje...
# comp.os.ms-windows.misc/9618    From: csyphers@uafhp..uark.edu (Chris Syphers)...
# comp.sys.mac.hardware/51613     From: nodine@lcs.mit.edu (Mark H. Nodine)\nSub...
# comp.graphics/37915             From: kph2q@onyx.cs.Virginia.EDU (Kenneth Hinc...
# sci.electronics/53670           From: nagle@netcom.com (John Nagle)\nSubject: ...
# rec.sport.baseball/104428       From: r4938585@joplin.biosci.arizona.edu (Doug...
# soc.religion.christian/20558    From: jonh@david.wheaton.edu (Jonathan Hayward...
# rec.autos/102990                From: jimf@centerline.com (Jim Frost)\nSubject...
# ...                                                                           ...
# comp.sys.mac.hardware/51932     Distribution: world\nFrom: elenay_creations@tc...
# rec.sport.baseball/104363       From: re4@prism.gatech.EDU (RUSSELL EARNEST)\n...
# sci.space/61176                 From: looper@cco.caltech.edu (Mark D. Looper)\...
# rec.sport.hockey/53762          From: gballent@hudson.UVic.CA (Greg  Ballentin...
# rec.autos/103003                From: cka52397@uxa.cso.uiuc.edu (OrioleFan@uiu...
# comp.graphics/38501             From: max@slinky.NYU.EDU (David Max)\nSubject:...
# comp.sys.mac.hardware/51823     From: hades@coos.dartmouth.edu (Brian V. Hughe...
# rec.autos/103185                From: c23reg@kocrsv01.delcoelect.com (Ron Gask...
# rec.autos/102914                From: callison@uokmax.ecn.uoknor.edu (James P....
# misc.forsale/74811              From: bigelos@hobo.ECE.ORST.EDU (Space Gigolo)...
# rec.sport.hockey/53809          From: LMARSHA@cms.cc.wayne.edu (Laurie Marshal...
# comp.sys.ibm.pc.hardware/60156  From: gt5735a@prism.gatech.EDU (Mark Devaney)\...
# rec.sport.baseball/102644       From: pkeenan@s.psych.uiuc.edu (Patricia Keena...
# comp.sys.ibm.pc.hardware/60715  From: CCMB <CCMB@MUSICA.MCGILL.CA>\nSubject: W...
# rec.sport.hockey/53979          From: cbetz@radioman.cray.com (Charles Betz  {...
# talk.politics.mideast/76308     From: 2120788@hydra.maths.unsw.EDU.AU ()\nSubj...
# soc.religion.christian/20902    From: aa888@freenet.carleton.ca (Mark Baker)\n...
# misc.forsale/76576              From: zmed16@trc.amoco.com (Michael)\nSubject:...
# sci.crypt/15607                 From: rdippold@qualcomm.com (Ron "Asbestos" Di...
# comp.sys.mac.hardware/51725     From: bchuang@css.itd.umich.edu (Ben Chuang)\n...
# talk.religion.misc/84087        From: Pegasus@aaa.uoregon.edu (Pegasus)\nSubje...
# talk.politics.mideast/75982     From: shaig@composer.think.com (Shai Guday)\nS...
# comp.sys.ibm.pc.hardware/60496  From: mrj@cs.su.oz.au (Mark James)\nSubject: R...
# misc.forsale/76143              From: chein@eng.auburn.edu (Tsan Heui)\nSubjec...
# comp.windows.x/66943            From: adrian@ora.COM (Adrian Nye)\nSubject: im...
# sci.med/58069                   From: jim.zisfein@factory.com (Jim Zisfein) \n...
# comp.sys.mac.hardware/51712     From: ebodin@pearl.tufts.edu\nSubject: Screen ...
# comp.sys.ibm.pc.hardware/60695  From: westes@netcom.com (Will Estes)\nSubject:...
# comp.graphics/38319             From: steve@hcrlgw (Steven Collins)\nSubject: ...
# rec.motorcycles/104440          From: gunning@cco.caltech.edu (Kevin J. Gunnin...
#
#                                                                        text_clean
# doc_id
# rec.autos/102994                from thing subject what car organ univers mary...
# comp.sys.mac.hardware/51861     from guy kuo subject si clock poll final call ...
# comp.sys.mac.hardware/51879     from thoma e willi subject pb question organ p...
# comp.graphics/38242             from jgreen joe green subject re weitek organ ...
# sci.space/60880                 from jonathan mcdowel subject re shuttl launch...
# talk.politics.guns/54525        from foxvog dougla subject re reword second am...
# sci.med/58080                   from brian man delaney subject brain tumor tre...
# comp.sys.ibm.pc.hardware/60249  from grubb subject re ide vs scsi organ new me...
# comp.os.ms-windows.misc/10008   from subject win icon help pleas organ univers...
# comp.sys.mac.hardware/50502     from stan kerr subject re sigma design doubl d...
# rec.motorcycles/104091          from irwin arnstein subject re recommend duc s...
# talk.religion.misc/83457        from david bold subject re question popular mo...
# comp.sys.mac.hardware/51621     from rod cerkoney subject fekvh organ hewlett ...
# sci.space/61165                 from david b mckissock subject re space statio...
# misc.forsale/76142              from johnni l lee subject re move sale summari...
# alt.atheism/51242               from mathew subject re polit atheist organ man...
# comp.graphics/38633             from allen b subject re tiff philosoph signifi...
# rec.autos/102812                from kevin parker subject insur rate perform c...
# sci.electronics/52816           from subject seek thermocoupl amplifi circuit ...
# comp.windows.x/67212            from ann mari barden subject config file quest...
# alt.atheism/53216               from keith allan schneider subject re pompou a...
# rec.sport.hockey/53747          from gari leung subject re nhl team captain or...
# misc.forsale/75973              from rpwhite subject re catalog pc enhanc repo...
# comp.os.ms-windows.misc/9618    from csypher chri sypher subject re do font si...
# comp.sys.mac.hardware/51613     from mark h nodin subject re quadra scsi probl...
# comp.graphics/37915             from kenneth hinckley subject voic input vendo...
# sci.electronics/53670           from john nagl subject re what nuclear cool to...
# rec.sport.baseball/104428       from doug robert subject re nl vs al organ uni...
# soc.religion.christian/20558    from jonathan hayward subject re pantheism env...
# rec.autos/102990                from jim frost subject re is car saftey import...
# ...                                                                           ...
# comp.sys.mac.hardware/51932     distribut world from anthoni d saxton organ cy...
# rec.sport.baseball/104363       from russel earnest subject re player rush maj...
# sci.space/61176                 from mark d looper subject re command loss tim...
# rec.sport.hockey/53762          from greg ballentin subject re wing win organ ...
# rec.autos/103003                from oriolefan subject re opel owner organ uni...
# comp.graphics/38501             from david max subject mode speedstar summari ...
# comp.sys.mac.hardware/51823     from brian v hugh subject re centri math copro...
# rec.autos/103185                from ron gaskin subject re dumbest automot con...
# rec.autos/102914                from jame p callison subject re warn pleas rea...
# misc.forsale/74811              from space gigolo subject laser printer forsal...
# rec.sport.hockey/53809          from lauri marshal subject re if you were pat ...
# comp.sys.ibm.pc.hardware/60156  from mark devaney subject sorri anoth gateway ...
# rec.sport.baseball/102644       from patricia keenan subject re quick easi que...
# comp.sys.ibm.pc.hardware/60715  from ccmb subject what system use line organ m...
# rec.sport.hockey/53979          from charl betz cf eng subject nhl team milwau...
# talk.politics.mideast/76308     from subject re organ school mathemat unsw lin...
# soc.religion.christian/20902    from mark baker subject re the arrog christian...
# misc.forsale/76576              from michael subject for sale drum machin orig...
# sci.crypt/15607                 from ron asbesto dippold subject re onc tap co...
# comp.sys.mac.hardware/51725     from ben chuang subject tcp ip rout organ univ...
# talk.religion.misc/84087        from pegasu subject re merlin mithra magick or...
# talk.politics.mideast/75982     from shai guday subject re go hezbollah organ ...
# comp.sys.ibm.pc.hardware/60496  from mark jame subject re ide vs scsi whi vlb ...
# misc.forsale/76143              from tsan heui subject in case a deal is a lem...
# comp.windows.x/66943            from adrian nye subject imak book review organ...
# sci.med/58069                   from jim zisfein subject re migrain scan distr...
# comp.sys.mac.hardware/51712     from subject screen death mac plu line organ t...
# comp.sys.ibm.pc.hardware/60695  from will est subject mount cpu cooler vertic ...
# comp.graphics/38319             from steve steven collin subject re sphere poi...
# rec.motorcycles/104440          from kevin j gun subject stolen cbr organ cali...
#
# [11314 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['text_clean'])

print(X.shape)
print(vectorizer.get_feature_names())
# Out:
# (11314, 56567)
# ['aa', 'aaa', 'aaaa', 'aaaaaaaaaaaa', 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaauuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuugggggggggggggggg', 'aaaaagggghhhh', 'aaaarrgghhhh', 'aaah', 'aaahh', 'aaahhhh', 'aaai', 'aab', 'aacc', 'aachen', 'aacvkc', 'aaef', 'aaf', 'aah', 'aalac', 'aalborg', 'aalm', 'aaltern', 'aam', 'aamaz', 'aamir', 'aammmaaaazzzzzziinnnnggggg', 'aan', 'aanbieden', 'aanerud', 'aangeboden', 'aangegeven', 'aangezien', 'aanp', 'aantal', 'aao', 'aap', 'aargh', 'aarghhhh', 'aarhu', 'aario', 'aaron', 'aaronson', 'aarp', 'aarseth', 'aarskog', 'aask', 'aatchoo', 'aauwpiugyv', 'aav', 'aavso', 'aaw', 'aax', 'aayau', 'aazaade', 'aazo', 'ab', 'abab', 'abacu', 'abad', 'abaihm', 'abandon', 'abandond', 'abat', 'abba', 'abbasid', 'abber', 'abberley', 'abbey', 'abbi', 'abbot', 'abbott', 'abboud', 'abbrev', 'abbrevi', 'abc', 'abcdef', 'abcpv', 'abd', 'abdel', 'abdi', 'abdic', 'abdkw', 'abdo', 'abdomen', 'abdomin', 'abduct', 'abdul', 'abdulcebbar', 'abdulhamid', 'abdullah', 'abdullahad', 'abe', 'abedk', 'abeel', 'abeit', 'abeka', 'abel', 'aben', 'abensberg', 'abeoz', 'aber', 'aberdeen', 'abernathi', 'aberr', 'aberystwyth', 'abett', 'abfb', 'abfdefghiijklmmnohpp', 'abg', 'abgarovich', 'abgc', 'abhin', 'abhor', 'abhorr', 'abhout', 'abi', 'abian', 'abid', 'abideth', 'abig', 'abigail', 'abil', 'abildskov', 'abilen', 'abiliy', 'abingdon', 'abington', 'abiogenesi', 'abj', 'abkect', 'abkhazia', 'abl', 'ablaz', 'abli', 'ablil', 'abner', 'abnorm', 'abnt', 'abo', 'aboard', 'aboc', 'abod', 'aboid', 'abolish', 'abolit', 'abolitionist', 'abomb', 'abomin', 'aboov', 'abord', 'aboritionist', 'abort', 'abott', 'abotu', 'abou', 'abound', 'about', 'abov', 'abovax', 'abovement', 'abovew', 'abp', 'abph', 'abpsoft', 'abput', 'abraam', 'abraham', 'abram', 'abramyan', 'abras', 'abrash', 'abreast', 'abridg', 'abroad', 'abrog', 'abrupt', 'abruptli', 'abscenc', 'abscess', 'absenc', 'absens', 'absent', 'absente', 'absitin', 'absolut', 'absolutey', 'absolutist', 'absolv', 'absood', 'absorb', 'absorbt', 'absorpt', 'absoultli', 'abstact', 'abstain', 'abstin', 'abstinencn', 'abstract', 'absurb', 'absurd', 'absurdium', 'absurdli', 'absurdum', 'abt', 'abu', 'abulfaz', 'abund', 'abundantli', 'abuot', 'abus', 'abut', 'abv', 'abviou', 'abvz', 'abysm', 'abyss', 'abyt', 'abz', 'ac', 'aca', 'acad', 'acadami', 'acadamia', 'academ', 'academi', 'academia', 'academica', 'academician', 'acadia', 'acadien', 'acb', 'acbl', 'acc', 'acced', 'accel', 'accelar', 'accelarator', 'accelartor', 'acceleart', 'acceler', 'acceleratortext', 'acceller', 'accent', 'accentu', 'accept', 'acceptab', 'acces', 'accesori', 'access', 'accessari', 'accessdata', 'accessori', 'accesssori', 'accid', 'accident', 'acclaim', 'acclim', 'acclimat', 'acclimitaz', 'accolad', 'accom', 'accomazzi', 'accommod', 'accomod', 'accompani', 'accompli', 'accomplic', 'accomplish', 'accoount', 'accor', 'accord', 'accordingli', 'accordion', 'accordiong', 'accost', 'accound', 'account', 'accpet', 'accredit', 'accret', 'accreti', 'accretieschijven', 'accrodingli', 'accross', 'accru', 'accsi', 'accton', 'accuart', 'accuat', 'accucolor', 'accucorp', 'accufont', 'accuir', 'accukey', 'acculog', 'accuml', 'accummul', 'accumul', 'accupunctur', 'accupuntunc', 'accur', 'accuraci', 'accus', 'accusor', 'accuss', 'accustom', 'accutan', 'accutrak', 'acd', 'acdi', 'ace', 'acegr', 'aceh', 'aceituna', 'aceler', 'acem', 'acept', 'acer', 'acess', 'acet', 'acetominophen', 'acetylen', 'acgi', 'ach', 'achaemenid', 'achaeminid', 'acham', 'achar', 'acheamenid', 'acheiv', 'achevia', 'achi', 'achiev', 'achieva', 'achil', 'achim', 'achiv', 'achkar', 'achs', 'acht', 'achtung', 'achurist', 'achx', 'achz', 'achzd', 'achzq', 'achzrlj', 'aci', 'acid', 'acidophil', 'acidophili', 'acidophiliu', 'acidophilu', 'acifu', 'acii', 'aciid', 'acj', 'ack', 'acker', 'ackermann', 'acknosledg', 'acknowled', 'acknowledg', 'acknowleg', 'aclim', 'aclimat', 'aclj', 'aclu', 'acm', 'acn', 'acord', 'acorn', 'acosta', 'acoust', 'acoustiqu', 'acp', 'acq', 'acquaint', 'acquaintac', 'acquiesc', 'ac ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity_matrix = cosine_similarity(X, X)

# %%
import numpy as np

def recommend_articles(doc_id, top_n=10, similarity_matrix=similarity_matrix):
    indexed_doc_ids = pd.Series(df.index)

    matched_row_number = indexed_doc_ids[indexed_doc_ids == doc_id].index[0]

    matched_row = pd.Series(similarity_matrix[matched_row_number])

    sorted_recommendations = matched_row.sort_values(ascending=False)

    top_n_recommendations = sorted_recommendations[1:(top_n + 1)]
    
    return pd.DataFrame({
        'doc_id': indexed_doc_ids[top_n_recommendations.index].values,
        'similarity': top_n_recommendations.values
    }).set_index('doc_id')

# %%
recommend_articles('comp.sys.mac.hardware/51861', top_n=20)
# Out:
#                                 similarity
# doc_id
# comp.sys.mac.hardware/51695       0.648966
# comp.sys.mac.hardware/51674       0.440609
# comp.sys.mac.hardware/51560       0.433631
# comp.sys.mac.hardware/51920       0.374815
# comp.sys.mac.hardware/51642       0.273637
# comp.sys.mac.hardware/51906       0.269982
# comp.sys.mac.hardware/51708       0.247467
# comp.sys.mac.hardware/51747       0.214782
# comp.sys.mac.hardware/51745       0.195968
# comp.sys.mac.hardware/50551       0.189666
# comp.sys.mac.hardware/51507       0.188438
# comp.sys.mac.hardware/51895       0.183884
# comp.sys.ibm.pc.hardware/60199    0.160745
# talk.politics.misc/178343         0.158810
# comp.os.ms-windows.misc/9935      0.158280
# comp.sys.mac.hardware/51707       0.151621
# comp.sys.ibm.pc.hardware/60740    0.151191
# comp.sys.mac.hardware/51652       0.144992
# comp.sys.mac.hardware/51636       0.143179
# comp.sys.mac.hardware/51628       0.141039
