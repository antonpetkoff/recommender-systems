# %%
from sklearn.datasets import fetch_20newsgroups

newsgroups_train = fetch_20newsgroups(subset='train')

# %%
import pandas as pd

df = pd.DataFrame({
    'doc_id': list(map(lambda filename: '/'.join(filename.split('/')[-2:]), newsgroups_train.filenames)),
    'topic': list(map(lambda topic_id: newsgroups_train.target_names[topic_id], newsgroups_train.target)),
    'text': newsgroups_train.data,
})

df
# Out:
#                                doc_id                     topic  \
# 0                    rec.autos/102994                 rec.autos
# 1         comp.sys.mac.hardware/51861     comp.sys.mac.hardware
# 2         comp.sys.mac.hardware/51879     comp.sys.mac.hardware
# 3                 comp.graphics/38242             comp.graphics
# 4                     sci.space/60880                 sci.space
# 5            talk.politics.guns/54525        talk.politics.guns
# 6                       sci.med/58080                   sci.med
# 7      comp.sys.ibm.pc.hardware/60249  comp.sys.ibm.pc.hardware
# 8       comp.os.ms-windows.misc/10008   comp.os.ms-windows.misc
# 9         comp.sys.mac.hardware/50502     comp.sys.mac.hardware
# 10             rec.motorcycles/104091           rec.motorcycles
# 11           talk.religion.misc/83457        talk.religion.misc
# 12        comp.sys.mac.hardware/51621     comp.sys.mac.hardware
# 13                    sci.space/61165                 sci.space
# 14                 misc.forsale/76142              misc.forsale
# 15                  alt.atheism/51242               alt.atheism
# 16                comp.graphics/38633             comp.graphics
# 17                   rec.autos/102812                 rec.autos
# 18              sci.electronics/52816           sci.electronics
# 19               comp.windows.x/67212            comp.windows.x
# 20                  alt.atheism/53216               alt.atheism
# 21             rec.sport.hockey/53747          rec.sport.hockey
# 22                 misc.forsale/75973              misc.forsale
# 23       comp.os.ms-windows.misc/9618   comp.os.ms-windows.misc
# 24        comp.sys.mac.hardware/51613     comp.sys.mac.hardware
# 25                comp.graphics/37915             comp.graphics
# 26              sci.electronics/53670           sci.electronics
# 27          rec.sport.baseball/104428        rec.sport.baseball
# 28       soc.religion.christian/20558    soc.religion.christian
# 29                   rec.autos/102990                 rec.autos
# ...                               ...                       ...
# 11284     comp.sys.mac.hardware/51932     comp.sys.mac.hardware
# 11285       rec.sport.baseball/104363        rec.sport.baseball
# 11286                 sci.space/61176                 sci.space
# 11287          rec.sport.hockey/53762          rec.sport.hockey
# 11288                rec.autos/103003                 rec.autos
# 11289             comp.graphics/38501             comp.graphics
# 11290     comp.sys.mac.hardware/51823     comp.sys.mac.hardware
# 11291                rec.autos/103185                 rec.autos
# 11292                rec.autos/102914                 rec.autos
# 11293              misc.forsale/74811              misc.forsale
# 11294          rec.sport.hockey/53809          rec.sport.hockey
# 11295  comp.sys.ibm.pc.hardware/60156  comp.sys.ibm.pc.hardware
# 11296       rec.sport.baseball/102644        rec.sport.baseball
# 11297  comp.sys.ibm.pc.hardware/60715  comp.sys.ibm.pc.hardware
# 11298          rec.sport.hockey/53979          rec.sport.hockey
# 11299     talk.politics.mideast/76308     talk.politics.mideast
# 11300    soc.religion.christian/20902    soc.religion.christian
# 11301              misc.forsale/76576              misc.forsale
# 11302                 sci.crypt/15607                 sci.crypt
# 11303     comp.sys.mac.hardware/51725     comp.sys.mac.hardware
# 11304        talk.religion.misc/84087        talk.religion.misc
# 11305     talk.politics.mideast/75982     talk.politics.mideast
# 11306  comp.sys.ibm.pc.hardware/60496  comp.sys.ibm.pc.hardware
# 11307              misc.forsale/76143              misc.forsale
# 11308            comp.windows.x/66943            comp.windows.x
# 11309                   sci.med/58069                   sci.med
# 11310     comp.sys.mac.hardware/51712     comp.sys.mac.hardware
# 11311  comp.sys.ibm.pc.hardware/60695  comp.sys.ibm.pc.hardware
# 11312             comp.graphics/38319             comp.graphics
# 11313          rec.motorcycles/104440           rec.motorcycles
#
#                                                     text
# 0      From: lerxst@wam.umd.edu (where's my thing)\nS...
# 1      From: guykuo@carson.u.washington.edu (Guy Kuo)...
# 2      From: twillis@ec.ecn.purdue.edu (Thomas E Will...
# 3      From: jgreen@amber (Joe Green)\nSubject: Re: W...
# 4      From: jcm@head-cfa.harvard.edu (Jonathan McDow...
# 5      From: dfo@vttoulu.tko.vtt.fi (Foxvog Douglas)\...
# 6      From: bmdelane@quads.uchicago.edu (brian manni...
# 7      From: bgrubb@dante.nmsu.edu (GRUBB)\nSubject: ...
# 8      From: holmes7000@iscsvax.uni.edu\nSubject: WIn...
# 9      From: kerr@ux1.cso.uiuc.edu (Stan Kerr)\nSubje...
# 10     From: irwin@cmptrc.lonestar.org (Irwin Arnstei...
# 11     From: david@terminus.ericsson.se (David Bold)\...
# 12     From: rodc@fc.hp.com (Rod Cerkoney)\nSubject: ...
# 13     From: dbm0000@tm0006.lerc.nasa.gov (David B. M...
# 14     From: jllee@acsu.buffalo.edu (Johnny L Lee)\nS...
# 15     From: mathew <mathew@mantis.co.uk>\nSubject: R...
# 16     From: ab@nova.cc.purdue.edu (Allen B)\nSubject...
# 17     From: CPKJP@vm.cc.latech.edu (Kevin Parker)\nS...
# 18     From: ritley@uimrl7.mrl.uiuc.edu ()\nSubject: ...
# 19     From: abarden@tybse1.uucp (Ann Marie Barden)\n...
# 20     From: keith@cco.caltech.edu (Keith Allan Schne...
# 21     From: leunggm@odin.control.utoronto.ca (Gary L...
# 22     From: rpwhite@cs.nps.navy.mil (rpwhite)\nSubje...
# 23     From: csyphers@uafhp..uark.edu (Chris Syphers)...
# 24     From: nodine@lcs.mit.edu (Mark H. Nodine)\nSub...
# 25     From: kph2q@onyx.cs.Virginia.EDU (Kenneth Hinc...
# 26     From: nagle@netcom.com (John Nagle)\nSubject: ...
# 27     From: r4938585@joplin.biosci.arizona.edu (Doug...
# 28     From: jonh@david.wheaton.edu (Jonathan Hayward...
# 29     From: jimf@centerline.com (Jim Frost)\nSubject...
# ...                                                  ...
# 11284  Distribution: world\nFrom: elenay_creations@tc...
# 11285  From: re4@prism.gatech.EDU (RUSSELL EARNEST)\n...
# 11286  From: looper@cco.caltech.edu (Mark D. Looper)\...
# 11287  From: gballent@hudson.UVic.CA (Greg  Ballentin...
# 11288  From: cka52397@uxa.cso.uiuc.edu (OrioleFan@uiu...
# 11289  From: max@slinky.NYU.EDU (David Max)\nSubject:...
# 11290  From: hades@coos.dartmouth.edu (Brian V. Hughe...
# 11291  From: c23reg@kocrsv01.delcoelect.com (Ron Gask...
# 11292  From: callison@uokmax.ecn.uoknor.edu (James P....
# 11293  From: bigelos@hobo.ECE.ORST.EDU (Space Gigolo)...
# 11294  From: LMARSHA@cms.cc.wayne.edu (Laurie Marshal...
# 11295  From: gt5735a@prism.gatech.EDU (Mark Devaney)\...
# 11296  From: pkeenan@s.psych.uiuc.edu (Patricia Keena...
# 11297  From: CCMB <CCMB@MUSICA.MCGILL.CA>\nSubject: W...
# 11298  From: cbetz@radioman.cray.com (Charles Betz  {...
# 11299  From: 2120788@hydra.maths.unsw.EDU.AU ()\nSubj...
# 11300  From: aa888@freenet.carleton.ca (Mark Baker)\n...
# 11301  From: zmed16@trc.amoco.com (Michael)\nSubject:...
# 11302  From: rdippold@qualcomm.com (Ron "Asbestos" Di...
# 11303  From: bchuang@css.itd.umich.edu (Ben Chuang)\n...
# 11304  From: Pegasus@aaa.uoregon.edu (Pegasus)\nSubje...
# 11305  From: shaig@composer.think.com (Shai Guday)\nS...
# 11306  From: mrj@cs.su.oz.au (Mark James)\nSubject: R...
# 11307  From: chein@eng.auburn.edu (Tsan Heui)\nSubjec...
# 11308  From: adrian@ora.COM (Adrian Nye)\nSubject: im...
# 11309  From: jim.zisfein@factory.com (Jim Zisfein) \n...
# 11310  From: ebodin@pearl.tufts.edu\nSubject: Screen ...
# 11311  From: westes@netcom.com (Will Estes)\nSubject:...
# 11312  From: steve@hcrlgw (Steven Collins)\nSubject: ...
# 11313  From: gunning@cco.caltech.edu (Kevin J. Gunnin...
#
# [11314 rows x 3 columns]
