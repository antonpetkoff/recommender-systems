# %%
from sklearn.datasets import fetch_20newsgroups

newsgroups_train = fetch_20newsgroups(subset='train')

# %%
import pandas as pd

df = pd.DataFrame({
    'doc_id': list(map(lambda filename: '/'.join(filename.split('/')[-2:]), newsgroups_train.filenames)),
    'topic': list(map(lambda topic_id: newsgroups_train.target_names[topic_id], newsgroups_train.target)),
    'text': newsgroups_train.data,
})

df = df.set_index('doc_id')

df
# Out:
#                                                    topic  \
# doc_id
# rec.autos/102994                               rec.autos
# comp.sys.mac.hardware/51861        comp.sys.mac.hardware
# comp.sys.mac.hardware/51879        comp.sys.mac.hardware
# comp.graphics/38242                        comp.graphics
# sci.space/60880                                sci.space
# talk.politics.guns/54525              talk.politics.guns
# sci.med/58080                                    sci.med
# comp.sys.ibm.pc.hardware/60249  comp.sys.ibm.pc.hardware
# comp.os.ms-windows.misc/10008    comp.os.ms-windows.misc
# comp.sys.mac.hardware/50502        comp.sys.mac.hardware
# rec.motorcycles/104091                   rec.motorcycles
# talk.religion.misc/83457              talk.religion.misc
# comp.sys.mac.hardware/51621        comp.sys.mac.hardware
# sci.space/61165                                sci.space
# misc.forsale/76142                          misc.forsale
# alt.atheism/51242                            alt.atheism
# comp.graphics/38633                        comp.graphics
# rec.autos/102812                               rec.autos
# sci.electronics/52816                    sci.electronics
# comp.windows.x/67212                      comp.windows.x
# alt.atheism/53216                            alt.atheism
# rec.sport.hockey/53747                  rec.sport.hockey
# misc.forsale/75973                          misc.forsale
# comp.os.ms-windows.misc/9618     comp.os.ms-windows.misc
# comp.sys.mac.hardware/51613        comp.sys.mac.hardware
# comp.graphics/37915                        comp.graphics
# sci.electronics/53670                    sci.electronics
# rec.sport.baseball/104428             rec.sport.baseball
# soc.religion.christian/20558      soc.religion.christian
# rec.autos/102990                               rec.autos
# ...                                                  ...
# comp.sys.mac.hardware/51932        comp.sys.mac.hardware
# rec.sport.baseball/104363             rec.sport.baseball
# sci.space/61176                                sci.space
# rec.sport.hockey/53762                  rec.sport.hockey
# rec.autos/103003                               rec.autos
# comp.graphics/38501                        comp.graphics
# comp.sys.mac.hardware/51823        comp.sys.mac.hardware
# rec.autos/103185                               rec.autos
# rec.autos/102914                               rec.autos
# misc.forsale/74811                          misc.forsale
# rec.sport.hockey/53809                  rec.sport.hockey
# comp.sys.ibm.pc.hardware/60156  comp.sys.ibm.pc.hardware
# rec.sport.baseball/102644             rec.sport.baseball
# comp.sys.ibm.pc.hardware/60715  comp.sys.ibm.pc.hardware
# rec.sport.hockey/53979                  rec.sport.hockey
# talk.politics.mideast/76308        talk.politics.mideast
# soc.religion.christian/20902      soc.religion.christian
# misc.forsale/76576                          misc.forsale
# sci.crypt/15607                                sci.crypt
# comp.sys.mac.hardware/51725        comp.sys.mac.hardware
# talk.religion.misc/84087              talk.religion.misc
# talk.politics.mideast/75982        talk.politics.mideast
# comp.sys.ibm.pc.hardware/60496  comp.sys.ibm.pc.hardware
# misc.forsale/76143                          misc.forsale
# comp.windows.x/66943                      comp.windows.x
# sci.med/58069                                    sci.med
# comp.sys.mac.hardware/51712        comp.sys.mac.hardware
# comp.sys.ibm.pc.hardware/60695  comp.sys.ibm.pc.hardware
# comp.graphics/38319                        comp.graphics
# rec.motorcycles/104440                   rec.motorcycles
#
#                                                                              text
# doc_id
# rec.autos/102994                From: lerxst@wam.umd.edu (where's my thing)\nS...
# comp.sys.mac.hardware/51861     From: guykuo@carson.u.washington.edu (Guy Kuo)...
# comp.sys.mac.hardware/51879     From: twillis@ec.ecn.purdue.edu (Thomas E Will...
# comp.graphics/38242             From: jgreen@amber (Joe Green)\nSubject: Re: W...
# sci.space/60880                 From: jcm@head-cfa.harvard.edu (Jonathan McDow...
# talk.politics.guns/54525        From: dfo@vttoulu.tko.vtt.fi (Foxvog Douglas)\...
# sci.med/58080                   From: bmdelane@quads.uchicago.edu (brian manni...
# comp.sys.ibm.pc.hardware/60249  From: bgrubb@dante.nmsu.edu (GRUBB)\nSubject: ...
# comp.os.ms-windows.misc/10008   From: holmes7000@iscsvax.uni.edu\nSubject: WIn...
# comp.sys.mac.hardware/50502     From: kerr@ux1.cso.uiuc.edu (Stan Kerr)\nSubje...
# rec.motorcycles/104091          From: irwin@cmptrc.lonestar.org (Irwin Arnstei...
# talk.religion.misc/83457        From: david@terminus.ericsson.se (David Bold)\...
# comp.sys.mac.hardware/51621     From: rodc@fc.hp.com (Rod Cerkoney)\nSubject: ...
# sci.space/61165                 From: dbm0000@tm0006.lerc.nasa.gov (David B. M...
# misc.forsale/76142              From: jllee@acsu.buffalo.edu (Johnny L Lee)\nS...
# alt.atheism/51242               From: mathew <mathew@mantis.co.uk>\nSubject: R...
# comp.graphics/38633             From: ab@nova.cc.purdue.edu (Allen B)\nSubject...
# rec.autos/102812                From: CPKJP@vm.cc.latech.edu (Kevin Parker)\nS...
# sci.electronics/52816           From: ritley@uimrl7.mrl.uiuc.edu ()\nSubject: ...
# comp.windows.x/67212            From: abarden@tybse1.uucp (Ann Marie Barden)\n...
# alt.atheism/53216               From: keith@cco.caltech.edu (Keith Allan Schne...
# rec.sport.hockey/53747          From: leunggm@odin.control.utoronto.ca (Gary L...
# misc.forsale/75973              From: rpwhite@cs.nps.navy.mil (rpwhite)\nSubje...
# comp.os.ms-windows.misc/9618    From: csyphers@uafhp..uark.edu (Chris Syphers)...
# comp.sys.mac.hardware/51613     From: nodine@lcs.mit.edu (Mark H. Nodine)\nSub...
# comp.graphics/37915             From: kph2q@onyx.cs.Virginia.EDU (Kenneth Hinc...
# sci.electronics/53670           From: nagle@netcom.com (John Nagle)\nSubject: ...
# rec.sport.baseball/104428       From: r4938585@joplin.biosci.arizona.edu (Doug...
# soc.religion.christian/20558    From: jonh@david.wheaton.edu (Jonathan Hayward...
# rec.autos/102990                From: jimf@centerline.com (Jim Frost)\nSubject...
# ...                                                                           ...
# comp.sys.mac.hardware/51932     Distribution: world\nFrom: elenay_creations@tc...
# rec.sport.baseball/104363       From: re4@prism.gatech.EDU (RUSSELL EARNEST)\n...
# sci.space/61176                 From: looper@cco.caltech.edu (Mark D. Looper)\...
# rec.sport.hockey/53762          From: gballent@hudson.UVic.CA (Greg  Ballentin...
# rec.autos/103003                From: cka52397@uxa.cso.uiuc.edu (OrioleFan@uiu...
# comp.graphics/38501             From: max@slinky.NYU.EDU (David Max)\nSubject:...
# comp.sys.mac.hardware/51823     From: hades@coos.dartmouth.edu (Brian V. Hughe...
# rec.autos/103185                From: c23reg@kocrsv01.delcoelect.com (Ron Gask...
# rec.autos/102914                From: callison@uokmax.ecn.uoknor.edu (James P....
# misc.forsale/74811              From: bigelos@hobo.ECE.ORST.EDU (Space Gigolo)...
# rec.sport.hockey/53809          From: LMARSHA@cms.cc.wayne.edu (Laurie Marshal...
# comp.sys.ibm.pc.hardware/60156  From: gt5735a@prism.gatech.EDU (Mark Devaney)\...
# rec.sport.baseball/102644       From: pkeenan@s.psych.uiuc.edu (Patricia Keena...
# comp.sys.ibm.pc.hardware/60715  From: CCMB <CCMB@MUSICA.MCGILL.CA>\nSubject: W...
# rec.sport.hockey/53979          From: cbetz@radioman.cray.com (Charles Betz  {...
# talk.politics.mideast/76308     From: 2120788@hydra.maths.unsw.EDU.AU ()\nSubj...
# soc.religion.christian/20902    From: aa888@freenet.carleton.ca (Mark Baker)\n...
# misc.forsale/76576              From: zmed16@trc.amoco.com (Michael)\nSubject:...
# sci.crypt/15607                 From: rdippold@qualcomm.com (Ron "Asbestos" Di...
# comp.sys.mac.hardware/51725     From: bchuang@css.itd.umich.edu (Ben Chuang)\n...
# talk.religion.misc/84087        From: Pegasus@aaa.uoregon.edu (Pegasus)\nSubje...
# talk.politics.mideast/75982     From: shaig@composer.think.com (Shai Guday)\nS...
# comp.sys.ibm.pc.hardware/60496  From: mrj@cs.su.oz.au (Mark James)\nSubject: R...
# misc.forsale/76143              From: chein@eng.auburn.edu (Tsan Heui)\nSubjec...
# comp.windows.x/66943            From: adrian@ora.COM (Adrian Nye)\nSubject: im...
# sci.med/58069                   From: jim.zisfein@factory.com (Jim Zisfein) \n...
# comp.sys.mac.hardware/51712     From: ebodin@pearl.tufts.edu\nSubject: Screen ...
# comp.sys.ibm.pc.hardware/60695  From: westes@netcom.com (Will Estes)\nSubject:...
# comp.graphics/38319             From: steve@hcrlgw (Steven Collins)\nSubject: ...
# rec.motorcycles/104440          From: gunning@cco.caltech.edu (Kevin J. Gunnin...
#
# [11314 rows x 2 columns]

# %%
from nltk.tokenize import TweetTokenizer
tweet_tok = TweetTokenizer()

from nltk.corpus import stopwords
stop_words = stopwords.words('english')

def clean_text(text):
    # TODO: remove metadata
    # TODO: Rake
    return [
        word.lower()
        for word in tweet_tok.tokenize(text)
        if word.isalpha() and not word in stop_words
    ]

# %%
sample = list(df['text'].head(2))
list(map(clean_text, sample))
# Out:
# [['from',
#   'thing',
#   'subject',
#   'what',
#   'car',
#   'organization',
#   'university',
#   'maryland',
#   'college',
#   'park',
#   'lines',
#   'i',
#   'wondering',
#   'anyone',
#   'could',
#   'enlighten',
#   'car',
#   'i',
#   'saw',
#   'day',
#   'it',
#   'door',
#   'sports',
#   'car',
#   'looked',
#   'late',
#   'early',
#   'it',
#   'called',
#   'bricklin',
#   'the',
#   'doors',
#   'really',
#   'small',
#   'in',
#   'addition',
#   'front',
#   'bumper',
#   'separate',
#   'rest',
#   'body',
#   'this',
#   'i',
#   'know',
#   'if',
#   'anyone',
#   'tellme',
#   'model',
#   'name',
#   'engine',
#   'specs',
#   'years',
#   'production',
#   'car',
#   'made',
#   'history',
#   'whatever',
#   'info',
#   'funky',
#   'looking',
#   'car',
#   'please',
#   'thanks',
#   'il',
#   'brought',
#   'neighborhood',
#   'lerxst'],
#  ['from',
#   'guy',
#   'kuo',
#   'subject',
#   'si',
#   'clock',
#   'poll',
#   'final',
#   'call',
#   'summary',
#   'final',
#   'call',
#   'si',
#   'clock',
#   'reports',
#   'keywords',
#   'si',
#   'acceleration',
#   'clock',
#   'upgrade',
#   'd',
#   'shelley',
#   'organization',
#   'university',
#   'washington',
#   'lines',
#   'a',
#   'fair',
#   'number',
#   'brave',
#   'souls',
#   'upgraded',
#   'si',
#   'clock',
#   'oscillator',
#   'shared',
#   'experiences',
#   'poll',
#   'please',
#   'send',
#   'brief',
#   'message',
#   'detailing',
#   'experiences',
#   'procedure',
#   'top',
#   'speed',
#   'attained',
#   'cpu',
#   'rated',
#   'speed',
#   'add',
#   'cards',
#   'adapters',
#   'heat',
#   'sinks',
#   'hour',
#   'usage',
#   'per',
#   'day',
#   'floppy',
#   'disk',
#   'functionality',
#   'floppies',
#   'especially',
#   'requested',
#   'i',
#   'summarizing',
#   'next',
#   'two',
#   'days',
#   'please',
#   'add',
#   'network',
#   'knowledge',
#   'base',
#   'done',
#   'clock',
#   'upgrade',
#   'answered',
#   'poll',
#   'thanks',
#   'guy',
#   'kuo']]

# %%
df['text_clean'] = df['text'].apply(clean_text).apply(lambda x: ' '.join(x))

# %%
df
# Out:
#                                                    topic  \
# doc_id
# rec.autos/102994                               rec.autos
# comp.sys.mac.hardware/51861        comp.sys.mac.hardware
# comp.sys.mac.hardware/51879        comp.sys.mac.hardware
# comp.graphics/38242                        comp.graphics
# sci.space/60880                                sci.space
# talk.politics.guns/54525              talk.politics.guns
# sci.med/58080                                    sci.med
# comp.sys.ibm.pc.hardware/60249  comp.sys.ibm.pc.hardware
# comp.os.ms-windows.misc/10008    comp.os.ms-windows.misc
# comp.sys.mac.hardware/50502        comp.sys.mac.hardware
# rec.motorcycles/104091                   rec.motorcycles
# talk.religion.misc/83457              talk.religion.misc
# comp.sys.mac.hardware/51621        comp.sys.mac.hardware
# sci.space/61165                                sci.space
# misc.forsale/76142                          misc.forsale
# alt.atheism/51242                            alt.atheism
# comp.graphics/38633                        comp.graphics
# rec.autos/102812                               rec.autos
# sci.electronics/52816                    sci.electronics
# comp.windows.x/67212                      comp.windows.x
# alt.atheism/53216                            alt.atheism
# rec.sport.hockey/53747                  rec.sport.hockey
# misc.forsale/75973                          misc.forsale
# comp.os.ms-windows.misc/9618     comp.os.ms-windows.misc
# comp.sys.mac.hardware/51613        comp.sys.mac.hardware
# comp.graphics/37915                        comp.graphics
# sci.electronics/53670                    sci.electronics
# rec.sport.baseball/104428             rec.sport.baseball
# soc.religion.christian/20558      soc.religion.christian
# rec.autos/102990                               rec.autos
# ...                                                  ...
# comp.sys.mac.hardware/51932        comp.sys.mac.hardware
# rec.sport.baseball/104363             rec.sport.baseball
# sci.space/61176                                sci.space
# rec.sport.hockey/53762                  rec.sport.hockey
# rec.autos/103003                               rec.autos
# comp.graphics/38501                        comp.graphics
# comp.sys.mac.hardware/51823        comp.sys.mac.hardware
# rec.autos/103185                               rec.autos
# rec.autos/102914                               rec.autos
# misc.forsale/74811                          misc.forsale
# rec.sport.hockey/53809                  rec.sport.hockey
# comp.sys.ibm.pc.hardware/60156  comp.sys.ibm.pc.hardware
# rec.sport.baseball/102644             rec.sport.baseball
# comp.sys.ibm.pc.hardware/60715  comp.sys.ibm.pc.hardware
# rec.sport.hockey/53979                  rec.sport.hockey
# talk.politics.mideast/76308        talk.politics.mideast
# soc.religion.christian/20902      soc.religion.christian
# misc.forsale/76576                          misc.forsale
# sci.crypt/15607                                sci.crypt
# comp.sys.mac.hardware/51725        comp.sys.mac.hardware
# talk.religion.misc/84087              talk.religion.misc
# talk.politics.mideast/75982        talk.politics.mideast
# comp.sys.ibm.pc.hardware/60496  comp.sys.ibm.pc.hardware
# misc.forsale/76143                          misc.forsale
# comp.windows.x/66943                      comp.windows.x
# sci.med/58069                                    sci.med
# comp.sys.mac.hardware/51712        comp.sys.mac.hardware
# comp.sys.ibm.pc.hardware/60695  comp.sys.ibm.pc.hardware
# comp.graphics/38319                        comp.graphics
# rec.motorcycles/104440                   rec.motorcycles
#
#                                                                              text  \
# doc_id
# rec.autos/102994                From: lerxst@wam.umd.edu (where's my thing)\nS...
# comp.sys.mac.hardware/51861     From: guykuo@carson.u.washington.edu (Guy Kuo)...
# comp.sys.mac.hardware/51879     From: twillis@ec.ecn.purdue.edu (Thomas E Will...
# comp.graphics/38242             From: jgreen@amber (Joe Green)\nSubject: Re: W...
# sci.space/60880                 From: jcm@head-cfa.harvard.edu (Jonathan McDow...
# talk.politics.guns/54525        From: dfo@vttoulu.tko.vtt.fi (Foxvog Douglas)\...
# sci.med/58080                   From: bmdelane@quads.uchicago.edu (brian manni...
# comp.sys.ibm.pc.hardware/60249  From: bgrubb@dante.nmsu.edu (GRUBB)\nSubject: ...
# comp.os.ms-windows.misc/10008   From: holmes7000@iscsvax.uni.edu\nSubject: WIn...
# comp.sys.mac.hardware/50502     From: kerr@ux1.cso.uiuc.edu (Stan Kerr)\nSubje...
# rec.motorcycles/104091          From: irwin@cmptrc.lonestar.org (Irwin Arnstei...
# talk.religion.misc/83457        From: david@terminus.ericsson.se (David Bold)\...
# comp.sys.mac.hardware/51621     From: rodc@fc.hp.com (Rod Cerkoney)\nSubject: ...
# sci.space/61165                 From: dbm0000@tm0006.lerc.nasa.gov (David B. M...
# misc.forsale/76142              From: jllee@acsu.buffalo.edu (Johnny L Lee)\nS...
# alt.atheism/51242               From: mathew <mathew@mantis.co.uk>\nSubject: R...
# comp.graphics/38633             From: ab@nova.cc.purdue.edu (Allen B)\nSubject...
# rec.autos/102812                From: CPKJP@vm.cc.latech.edu (Kevin Parker)\nS...
# sci.electronics/52816           From: ritley@uimrl7.mrl.uiuc.edu ()\nSubject: ...
# comp.windows.x/67212            From: abarden@tybse1.uucp (Ann Marie Barden)\n...
# alt.atheism/53216               From: keith@cco.caltech.edu (Keith Allan Schne...
# rec.sport.hockey/53747          From: leunggm@odin.control.utoronto.ca (Gary L...
# misc.forsale/75973              From: rpwhite@cs.nps.navy.mil (rpwhite)\nSubje...
# comp.os.ms-windows.misc/9618    From: csyphers@uafhp..uark.edu (Chris Syphers)...
# comp.sys.mac.hardware/51613     From: nodine@lcs.mit.edu (Mark H. Nodine)\nSub...
# comp.graphics/37915             From: kph2q@onyx.cs.Virginia.EDU (Kenneth Hinc...
# sci.electronics/53670           From: nagle@netcom.com (John Nagle)\nSubject: ...
# rec.sport.baseball/104428       From: r4938585@joplin.biosci.arizona.edu (Doug...
# soc.religion.christian/20558    From: jonh@david.wheaton.edu (Jonathan Hayward...
# rec.autos/102990                From: jimf@centerline.com (Jim Frost)\nSubject...
# ...                                                                           ...
# comp.sys.mac.hardware/51932     Distribution: world\nFrom: elenay_creations@tc...
# rec.sport.baseball/104363       From: re4@prism.gatech.EDU (RUSSELL EARNEST)\n...
# sci.space/61176                 From: looper@cco.caltech.edu (Mark D. Looper)\...
# rec.sport.hockey/53762          From: gballent@hudson.UVic.CA (Greg  Ballentin...
# rec.autos/103003                From: cka52397@uxa.cso.uiuc.edu (OrioleFan@uiu...
# comp.graphics/38501             From: max@slinky.NYU.EDU (David Max)\nSubject:...
# comp.sys.mac.hardware/51823     From: hades@coos.dartmouth.edu (Brian V. Hughe...
# rec.autos/103185                From: c23reg@kocrsv01.delcoelect.com (Ron Gask...
# rec.autos/102914                From: callison@uokmax.ecn.uoknor.edu (James P....
# misc.forsale/74811              From: bigelos@hobo.ECE.ORST.EDU (Space Gigolo)...
# rec.sport.hockey/53809          From: LMARSHA@cms.cc.wayne.edu (Laurie Marshal...
# comp.sys.ibm.pc.hardware/60156  From: gt5735a@prism.gatech.EDU (Mark Devaney)\...
# rec.sport.baseball/102644       From: pkeenan@s.psych.uiuc.edu (Patricia Keena...
# comp.sys.ibm.pc.hardware/60715  From: CCMB <CCMB@MUSICA.MCGILL.CA>\nSubject: W...
# rec.sport.hockey/53979          From: cbetz@radioman.cray.com (Charles Betz  {...
# talk.politics.mideast/76308     From: 2120788@hydra.maths.unsw.EDU.AU ()\nSubj...
# soc.religion.christian/20902    From: aa888@freenet.carleton.ca (Mark Baker)\n...
# misc.forsale/76576              From: zmed16@trc.amoco.com (Michael)\nSubject:...
# sci.crypt/15607                 From: rdippold@qualcomm.com (Ron "Asbestos" Di...
# comp.sys.mac.hardware/51725     From: bchuang@css.itd.umich.edu (Ben Chuang)\n...
# talk.religion.misc/84087        From: Pegasus@aaa.uoregon.edu (Pegasus)\nSubje...
# talk.politics.mideast/75982     From: shaig@composer.think.com (Shai Guday)\nS...
# comp.sys.ibm.pc.hardware/60496  From: mrj@cs.su.oz.au (Mark James)\nSubject: R...
# misc.forsale/76143              From: chein@eng.auburn.edu (Tsan Heui)\nSubjec...
# comp.windows.x/66943            From: adrian@ora.COM (Adrian Nye)\nSubject: im...
# sci.med/58069                   From: jim.zisfein@factory.com (Jim Zisfein) \n...
# comp.sys.mac.hardware/51712     From: ebodin@pearl.tufts.edu\nSubject: Screen ...
# comp.sys.ibm.pc.hardware/60695  From: westes@netcom.com (Will Estes)\nSubject:...
# comp.graphics/38319             From: steve@hcrlgw (Steven Collins)\nSubject: ...
# rec.motorcycles/104440          From: gunning@cco.caltech.edu (Kevin J. Gunnin...
#
#                                                                        text_clean
# doc_id
# rec.autos/102994                from thing subject what car organization unive...
# comp.sys.mac.hardware/51861     from guy kuo subject si clock poll final call ...
# comp.sys.mac.hardware/51879     from thomas e willis subject pb questions orga...
# comp.graphics/38242             from jgreen joe green subject re weitek organi...
# sci.space/60880                 from jonathan mcdowell subject re shuttle laun...
# talk.politics.guns/54525        from foxvog douglas subject re rewording secon...
# sci.med/58080                   from brian manning delaney subject brain tumor...
# comp.sys.ibm.pc.hardware/60249  from grubb subject re ide vs scsi organization...
# comp.os.ms-windows.misc/10008   from subject win icon help please organization...
# comp.sys.mac.hardware/50502     from stan kerr subject re sigma designs double...
# rec.motorcycles/104091          from irwin arnstein subject re recommendation ...
# talk.religion.misc/83457        from david bold subject re question popular mo...
# comp.sys.mac.hardware/51621     from rod cerkoney subject fekvh organization h...
# sci.space/61165                 from david b mckissock subject re space statio...
# misc.forsale/76142              from johnny l lee subject re moving sale summa...
# alt.atheism/51242               from mathew subject re political atheists orga...
# comp.graphics/38633             from allen b subject re tiff philosophical sig...
# rec.autos/102812                from kevin parker subject insurance rates perf...
# sci.electronics/52816           from subject seeking thermocouple amplifier ci...
# comp.windows.x/67212            from ann marie barden subject config file ques...
# alt.atheism/53216               from keith allan schneider subject re pompous ...
# rec.sport.hockey/53747          from gary leung subject re nhl team captains o...
# misc.forsale/75973              from rpwhite subject re catalog pc enhancement...
# comp.os.ms-windows.misc/9618    from csyphers chris syphers subject re dos fon...
# comp.sys.mac.hardware/51613     from mark h nodine subject re quadra scsi prob...
# comp.graphics/37915             from kenneth hinckley subject voice input vend...
# sci.electronics/53670           from john nagle subject re what nuclear coolin...
# rec.sport.baseball/104428       from doug roberts subject re nl vs al organiza...
# soc.religion.christian/20558    from jonathan hayward subject re pantheism env...
# rec.autos/102990                from jim frost subject re is car saftey import...
# ...                                                                           ...
# comp.sys.mac.hardware/51932     distribution world from anthony d saxton organ...
# rec.sport.baseball/104363       from russell earnest subject re players rushed...
# sci.space/61176                 from mark d looper subject re command loss tim...
# rec.sport.hockey/53762          from greg ballentine subject re wings win orga...
# rec.autos/103003                from oriolefan subject re opel owners organiza...
# comp.graphics/38501             from david max subject mode speedstar summary ...
# comp.sys.mac.hardware/51823     from brian v hughes subject re centris math co...
# rec.autos/103185                from ron gaskins subject re dumbest automotive...
# rec.autos/102914                from james p callison subject re warning pleas...
# misc.forsale/74811              from space gigolo subject laser printer forsal...
# rec.sport.hockey/53809          from laurie marshall subject re if you were pa...
# comp.sys.ibm.pc.hardware/60156  from mark devaney subject sorry another gatewa...
# rec.sport.baseball/102644       from patricia keenan subject re quick easy que...
# comp.sys.ibm.pc.hardware/60715  from ccmb subject what system using lines orga...
# rec.sport.hockey/53979          from charles betz cf eng subject nhl team milw...
# talk.politics.mideast/76308     from subject re organization school mathematic...
# soc.religion.christian/20902    from mark baker subject re the arrogance chris...
# misc.forsale/76576              from michael subject for sale drum machine ori...
# sci.crypt/15607                 from ron asbestos dippold subject re once tapp...
# comp.sys.mac.hardware/51725     from ben chuang subject tcp ip routing organiz...
# talk.religion.misc/84087        from pegasus subject re merlin mithras magick ...
# talk.politics.mideast/75982     from shai guday subject re go hezbollah organi...
# comp.sys.ibm.pc.hardware/60496  from mark james subject re ide vs scsi why vlb...
# misc.forsale/76143              from tsan heui subject in case a deal is a lem...
# comp.windows.x/66943            from adrian nye subject imake book review orga...
# sci.med/58069                   from jim zisfein subject re migraines scans di...
# comp.sys.mac.hardware/51712     from subject screen death mac plus lines organ...
# comp.sys.ibm.pc.hardware/60695  from will estes subject mounting cpu cooler ve...
# comp.graphics/38319             from steve steven collins subject re sphere po...
# rec.motorcycles/104440          from kevin j gunning subject stolen cbr organi...
#
# [11314 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['text_clean'])

print(X.shape)
print(vectorizer.get_feature_names())
# Out:
# (11314, 74955)
# ['aa', 'aaa', 'aaaa', 'aaaaaaaaaaaa', 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaauuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuugggggggggggggggg', 'aaaaagggghhhh', 'aaaarrgghhhh', 'aaah', 'aaahh', 'aaahhhh', 'aaai', 'aab', 'aacc', 'aachen', 'aacvkc', 'aaef', 'aaf', 'aah', 'aalac', 'aalborg', 'aalm', 'aalternate', 'aam', 'aamazing', 'aamir', 'aammmaaaazzzzzziinnnnggggg', 'aams', 'aan', 'aanbieden', 'aanerud', 'aangeboden', 'aangegeven', 'aangezien', 'aanp', 'aantal', 'aao', 'aap', 'aargh', 'aarghhhh', 'aarhus', 'aario', 'aaron', 'aaronson', 'aarp', 'aarseth', 'aarskog', 'aas', 'aasked', 'aatchoo', 'aauwpiugyv', 'aav', 'aavso', 'aaw', 'aax', 'aayau', 'aazaadee', 'aazo', 'ab', 'ababs', 'abacus', 'abad', 'abaihm', 'abandon', 'abandond', 'abandonded', 'abandoned', 'abandoning', 'abandonment', 'abandons', 'abate', 'abatement', 'abates', 'abba', 'abbasids', 'abberant', 'abberation', 'abberley', 'abbey', 'abbie', 'abbot', 'abbott', 'abboud', 'abbrev', 'abbreviated', 'abbreviation', 'abbreviations', 'abc', 'abcdef', 'abcpv', 'abd', 'abdel', 'abdi', 'abdication', 'abdkw', 'abdo', 'abdomen', 'abdomens', 'abdominal', 'abduct', 'abducted', 'abduction', 'abdul', 'abdulcebbar', 'abdulhamid', 'abdullah', 'abdullahad', 'abe', 'abedk', 'abeel', 'abeit', 'abekas', 'abel', 'aben', 'abensberg', 'abeoz', 'aber', 'aberdeen', 'abernathy', 'aberrant', 'aberration', 'aberrations', 'aberystwyth', 'abetter', 'abfb', 'abfdefghiijklmmnohpp', 'abg', 'abgarovich', 'abgc', 'abhin', 'abhor', 'abhorent', 'abhorred', 'abhorrences', 'abhorrent', 'abhout', 'abian', 'abide', 'abides', 'abideth', 'abiding', 'abig', 'abigail', 'abildskov', 'abilene', 'abilities', 'ability', 'abiliy', 'abingdon', 'abington', 'abiogenesis', 'abj', 'abkect', 'abkhazia', 'ablaze', 'ablazing', 'able', 'ablility', 'ably', 'abner', 'abnormal', 'abnormalities', 'abnormally', 'abnt', 'abo', 'aboard', 'aboce', 'abode', 'abodes', 'aboid', 'abolish', 'abolished', 'abolishing', 'abolishment', 'abolition', 'abolitionist', 'abolitionists', 'abomb', 'abominable', 'abomination', 'abominations', 'aboove', 'abord', 'aboritionists', 'abort', 'aborted', 'abortion', 'abortions', 'aborts', 'abott', 'abotu', 'abou', 'abound', 'abounded', 'abounds', 'about', 'abouts', 'abovax', 'above', 'abovementioned', 'abovew', 'abp', 'abph', 'abpsoft', 'abput', 'abraam', 'abraham', 'abrahamic', 'abram', 'abramyan', 'abrash', 'abrasions', 'abrasives', 'abreast', 'abridge', 'abridged', 'abridgement', 'abridgements', 'abridging', 'abridgment', 'abroad', 'abrogate', 'abrogation', 'abrupt', 'abruptly', 'abs', 'abscence', 'abscess', 'absence', 'absences', 'absense', 'absent', 'absentee', 'absitinence', 'absolut', 'absolute', 'absolutely', 'absolutes', 'absolutey', 'absolutism', 'absolutist', 'absolutists', 'absolve', 'absolved', 'absolving', 'absood', 'absorb', 'absorbed', 'absorber', 'absorbers', 'absorbing', 'absorbs', 'absorbtion', 'absorption', 'absoultly', 'abstact', 'abstacted', 'abstain', 'abstaining', 'abstinence', 'abstinencne', 'abstract', 'abstraction', 'abstractions', 'abstracts', 'absurb', 'absurd', 'absurdities', 'absurdity', 'absurdium', 'absurdly', 'absurdum', 'abt', 'abu', 'abue', 'abulfaz', 'abundance', 'abundances', 'abundant', 'abundantly', 'abuot', 'abus', 'abuse', 'abused', 'abuser', 'abusers', 'abuses', 'abusing', 'abusive', 'abutment', 'abve', 'abvious', 'abvz', 'aby', 'abysmal', 'abyss', 'abyte', 'abz', 'ac', 'aca', 'acad', 'acadamia', 'acadamy', 'academe', 'academia', 'academiae', 'academic', 'academica', 'academically', 'academician', 'academics', 'academies', 'academy', 'acadia', 'acadien', 'acb', 'acbl', 'acc', 'accede', 'accel', 'accelaration', 'accelarator', 'accelaratores', 'accelartor', 'acceleartion', 'acceler', 'accelerate', 'accelerated', 'accelerates', 'accelerating', 'acceleration', 'accelerations', 'accelerator', 'accelerators', 'acceleratortext', 'accellerated', 'accelleration', 'accellerator', 'accent', 'accented', 'accentuate', 'accentuates', 'accept', 'acceptab', 'acceptability', 'acceptable', 'acceptably', 'a ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity_matrix = cosine_similarity(X, X)

# %%
import numpy as np

def recommend_articles(doc_id, top_n=10, similarity_matrix=similarity_matrix):
    indexed_doc_ids = pd.Series(df.index)

    matched_row_number = indexed_doc_ids[indexed_doc_ids == doc_id].index[0]

    matched_row = pd.Series(similarity_matrix[matched_row_number])

    sorted_recommendations = matched_row.sort_values(ascending=False)

    top_n_recommendations = sorted_recommendations[1:(top_n + 1)]
    
    return pd.DataFrame({
        'doc_id': indexed_doc_ids[top_n_recommendations.index].values,
        'similarity': top_n_recommendations.values
    }).set_index('doc_id')

# %%
recommend_articles('comp.sys.mac.hardware/51861', top_n=20)
# Out:
# 6399    0.559158
# 1270    0.352043
# 4693    0.337164
# 9130    0.336613
# 9921    0.229659
# 2116    0.195919
# 8265    0.195876
# 5097    0.184398
# 9270    0.176560
# 5509    0.169636
# 5541    0.169029
# 2459    0.142756
# 6772    0.134662
# 685     0.131760
# 704     0.130924
# 450     0.125063
# 7246    0.123891
# 3035    0.122970
# 7284    0.122918
# 1501    0.121888
# dtype: float64
#                                 similarity
# doc_id
# comp.sys.mac.hardware/51695       0.559158
# comp.sys.mac.hardware/51560       0.352043
# comp.sys.mac.hardware/51920       0.337164
# comp.sys.mac.hardware/51674       0.336613
# comp.sys.mac.hardware/51708       0.229659
# comp.sys.mac.hardware/51747       0.195919
# comp.sys.mac.hardware/51906       0.195876
# comp.sys.mac.hardware/51745       0.184398
# comp.sys.mac.hardware/51642       0.176560
# comp.sys.mac.hardware/51895       0.169636
# comp.sys.mac.hardware/50551       0.169029
# comp.sys.mac.hardware/51507       0.142756
# comp.sys.mac.hardware/51636       0.134662
# comp.sys.ibm.pc.hardware/60740    0.131760
# comp.sys.mac.hardware/51881       0.130924
# comp.sys.ibm.pc.hardware/60652    0.125063
# comp.sys.ibm.pc.hardware/60615    0.123891
# comp.sys.ibm.pc.hardware/60199    0.122970
# comp.sys.ibm.pc.hardware/60568    0.122918
# comp.graphics/38495               0.121888
